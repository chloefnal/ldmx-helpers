# %%
from coffea import hist
import math

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import mplhep as hep
import numpy as np
plt.style.use(hep.style.CMS)

import awkward as ak

from matplotlib import colors
POPTS={'norm':colors.LogNorm()}

# %%
from data import getData, repackage
ldmx_dict = getData(chunks=True, fnames="/Users/chloeg/Desktop/Work/Fermilab2021/HistData/kaon_pn_4GeV_Jul1_ntuple/*.root")

# %%
def extend_array(arr, new_attr, new_attr_name):
    members={n:arr[n] for n in arr.fields}
    members[new_attr_name] = new_attr
    return ak.zip(members)

def add_angle(arr,br=['px','py','pz','e'],name="theta"):
    from coffea.nanoevents.methods import vector
    ak.behavior.update(vector.behavior)

    part =  ak.zip({"x": arr.px,
                    "y": arr.py,
                    "z": arr.pz,
                    "t": arr.e,
                    },
                    with_name="LorentzVector")
    arr = extend_array(arr, part.theta, name)
    return arr

def get_vector(arr):
    from coffea.nanoevents.methods import vector
    ak.behavior.update(vector.behavior)

    part =  ak.zip({"x": arr.px,
                    "y": arr.py,
                    "z": arr.pz,
                    "t": arr.e,
                    },
                    with_name="LorentzVector")
    return part

def flat(x,axis=None): # for now must cast while waiting for coffea to catch up
    try:
        return ak.to_numpy(ak.flatten(x,axis=axis)) 
    except:
        return x

# %%
hists = {}
hists["lambda_hist_dau1_proton"] = hist.Hist("Sim Lambda Dau",
                                hist.Bin("e", r"Kinetic Energy [MeV]", 80, 0, 1000)
                            )
hists["lambda_hist_dau2_proton"] = hist.Hist("Sim Lambda Dau",
                                hist.Bin("e", r"Kinetic Energy [MeV]", 80, 0, 1000)
                            )
hists["lambda_hist_dau1_piminus"] = hist.Hist("Sim Lambda Dau",
                                hist.Bin("e", r"Kinetic Energy [MeV]", 80, 0, 500)
                            )
hists["lambda_hist_dau2_piminus"] = hist.Hist("Sim Lambda Dau",
                                hist.Bin("e", r"Kinetic Energy [MeV]", 80, 0, 500)
                            )

# %%
def ProcessChunk(chunk, hists):
    ldmx_events = repackage(chunk)
    
    sim_lambda = ldmx_events['Sim_Lambda']
    sim_lambda_n = ldmx_events['n']['Sim_Lambda']
    sim_lambda_dau1 = ldmx_events['Sim_Lambda_dau1']
    sim_lambda_dau2 = ldmx_events['Sim_Lambda_dau2']
    
    lambda_pdgid = 3221
    pminus_pdgid = -211
    proton_pdgid = 2212
    
    decay_mask  = ((sim_lambda_dau2.momdecay)==1)

    lambdau1 = get_vector(sim_lambda_dau1[decay_mask])
    lambdau2 = get_vector(sim_lambda_dau2[decay_mask])
    
    dau1 = get_vector(sim_lambda_dau1[decay_mask])
    dau2 = get_vector(sim_lambda_dau2[decay_mask])
    
    theta1_mask = (lambdau1.theta*180/math.pi <= 40)
    theta2_mask = (lambdau2.theta*180/math.pi <= 40)

    
    proton_mask1  = ((flat(sim_lambda_dau1[decay_mask][theta1_mask & theta2_mask].pdgID)) == 2212)
    proton_mask2  = ((flat(sim_lambda_dau2[decay_mask][theta1_mask & theta2_mask].pdgID)) == 2212)
    piminus_mask1 = ((sim_lambda_dau1[decay_mask][theta1_mask & theta2_mask].pdgID) == -211)
    piminus_mask2 = ((sim_lambda_dau2[decay_mask][theta1_mask & theta2_mask].pdgID) == -211)
    #neutron_mask1 = ((flat(sim_lambda_dau1[decay_mask].pdgID)) == 2112)
    #neutron_mask2 = ((flat(sim_lambda_dau2[decay_mask].pdgID)) == 2112)
    #pi0_mask1 = ((sim_lambda_dau1[decay_mask].pdgID) == 111)
    #pi0_mask2 = ((sim_lambda_dau2[decay_mask].pdgID) == 111)

    proton_mass =  938.272
    neutron_mass = 939.565
    pi0_mass = 134.9768
    piminus_mass = 139.57039
    lambda0_mass = 1115.683
    kaon_mass = 497.648
    
    hists["lambda_hist_dau1_proton"].fill(
                         e=flat(dau1[proton_mask1].t)-proton_mass,
                         )   
    hists["lambda_hist_dau2_proton"].fill(
                         e=flat(dau2[proton_mask2].t)-proton_mass,
                         )   
    hists["lambda_hist_dau1_piminus"].fill(
                         e=flat(dau1[piminus_mask1].t)-piminus_mass,
                         )   
    hists["lambda_hist_dau2_piminus"].fill(
                         e=flat(dau2[piminus_mask2].t)-piminus_mass,
                         )  
    
    #hists["lambda_hist_dau1_neutron"].fill(
    #                     e=flat(dau1_d2[neutron_mask1].theta),
    #                     )   
    #hists["lambda_hist_dau2_neutron"].fill(
    #                     e=flat(dau2_d2[neutron_mask2].theta),
    #                     )  
    #hists["lambda_hist_dau1_pi0"].fill(
    #                     e=flat(dau1_d2[pi0_mask1].theta),
    #                     )   
    #hists["lambda_hist_dau2_pi0"].fill(
    #                     e=flat(dau2_d2[pi0_mask2].theta),
    #                     )  

    
    
    return

# %%
nchunk = 0
for chunk in ldmx_dict:
    #if nchunk >= 1: break
    nchunk += 1
    print('process',nchunk)
    ProcessChunk(chunk, hists)
# Out:
# process 1
# process 2
# process 3
# process 4
# process 5
# process 6
# process 7
# process 8
# process 9
# process 10
# process 11
# process 12
# process 13
# process 14
# process 15
# process 16
# process 17
# process 18
# process 19
# process 20
# process 21
# process 22
# process 23
# process 24
# process 25
# process 26
# process 27
# process 28
# process 29
# process 30
# process 31
# process 32
# process 33
# process 34
# process 35
# process 36
# process 37
# process 38
# process 39
# process 40
# process 41
# process 42
# process 43
# process 44
# process 45
# process 46
# process 47
# process 48
# process 49
# process 50
# process 51
# process 52
# process 53
# process 54
# process 55
# process 56
# process 57
# process 58
# process 59
# process 60
# process 61
# process 62
# process 63
# process 64
# process 65
# process 66
# process 67
# process 68
# process 69
# process 70
# process 71
# process 72
# process 73
# process 74
# process 75
# process 76
# process 77
# process 78
# process 79
# process 80
# process 81
# process 82
# process 83
# process 84
# process 85
# process 86
# process 87
# process 88
# process 89
# process 90
# process 91
# process 92
# process 93
# process 94
# process 95
# process 96
# process 97
# process 98
# process 99
# process 100
# process 101
# process 102
# process 103
# process 104
# process 105
# process 106
# process 107
# process 108
# process 109
# process 110
# process 111
# process 112
# process 113
# process 114
# process 115
# process 116
# process 117
# process 118
# process 119
# process 120
# process 121
# process 122
# process 123
# process 124
# process 125
# process 126
# process 127
# process 128
# process 129
# process 130
# process 131
# process 132
# process 133
# process 134
# process 135
# process 136
# process 137
# process 138
# process 139
# process 140
# process 141
# process 142
# process 143
# process 144
# process 145
# process 146
# process 147
# process 148
# process 149
# process 150
# process 151
# process 152
# process 153
# process 154
# process 155
# process 156
# process 157
# process 158
# process 159
# process 160
# process 161
# process 162
# process 163
# process 164
# process 165
# process 166
# process 167
# process 168
# process 169
# process 170
# process 171
# process 172
# process 173
# process 174
# process 175
# process 176
# process 177
# process 178
# process 179
# process 180
# process 181
# process 182
# process 183
# process 184
# process 185
# process 186
# process 187
# process 188
# process 189
# process 190
# process 191
# process 192
# process 193
# process 194
# process 195
# process 196
# process 197
# process 198
# process 199
# process 200
# process 201
# process 202
# process 203
# process 204
# process 205
# process 206
# process 207
# process 208
# process 209
# process 210
# process 211
# process 212
# process 213
# process 214
# process 215
# process 216
# process 217
# process 218
# process 219
# process 220
# process 221
# process 222
# process 223
# process 224
# process 225
# process 226
# process 227
# process 228
# process 229
# process 230
# process 231
# process 232
# process 233
# process 234
# process 235
# process 236
# process 237
# process 238
# process 239
# process 240
# process 241
# process 242
# process 243
# process 244
# process 245
# process 246
# process 247
# process 248
# process 249
# process 250
# process 251
# process 252
# process 253
# process 254
# process 255
# process 256
# process 257
# process 258
# process 259
# process 260
# process 261
# process 262
# process 263
# process 264
# process 265
# process 266
# process 267
# process 268
# process 269
# process 270
# process 271
# process 272
# process 273
# process 274
# process 275
# process 276
# process 277
# process 278
# process 279
# process 280
# process 281
# process 282
# process 283
# process 284
# process 285
# process 286
# process 287
# process 288
# process 289
# process 290
# process 291
# process 292
# process 293
# process 294
# process 295
# process 296
# process 297
# process 298
# process 299
# process 300
# process 301
# process 302
# process 303
# process 304
# process 305
# process 306
# process 307
# process 308
# process 309
# process 310
# process 311
# process 312
# process 313
# process 314
# process 315
# process 316
# process 317
# process 318
# process 319
# process 320
# process 321
# process 322
# process 323
# process 324
# process 325
# process 326
# process 327
# process 328
# process 329
# process 330
# process 331
# process 332
# process 333
# process 334
# process 335
# process 336
# process 337
# process 338
# process 339
# process 340
# process 341
# process 342
# process 343
# process 344
# process 345
# process 346
# process 347
# process 348
# process 349
# process 350
# process 351
# process 352
# process 353
# process 354
# process 355
# process 356
# process 357
# process 358
# process 359
# process 360

# %%
print(hists["lambda_hist_dau1_proton"])
fig, ax = plt.subplots()
hist.plot1d(hists["lambda_hist_dau1_proton"]+hists["lambda_hist_dau2_proton"],ax=ax,clear=False);
leg = ax.legend([r'$p^+$ Daughters with $\theta <40 ^\circ$'])

fig, ax = plt.subplots()
hist.plot1d(hists["lambda_hist_dau1_piminus"]+hists["lambda_hist_dau2_piminus"],ax=ax,clear=False);
leg = ax.legend([r'$\pi^-$ Daughters with $\theta <40 ^\circ$'])


#hist.plot1d(hists["lambda_hist_dau2_proton"],ax=ax,clear=False);
#ax.set_xlim(0, 30)
# Out:
# <Hist (e) instance at 0x1326ae9d0>
