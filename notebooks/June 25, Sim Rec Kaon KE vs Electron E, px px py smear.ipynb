# %%
from coffea import hist
import math

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.lines as lines
import mplhep as hep
import numpy as np
import random
plt.style.use(hep.style.CMS)

import awkward as ak

from matplotlib import colors
POPTS={'norm':colors.LogNorm(vmin=1,vmax=200)}

# %%
from data import getData, repackage
ldmx_dict = getData(chunks=True, fnames="/Users/chloeg/Desktop/Work/Fermilab2021/HistData/kshort_pn_4GeV_Jun13_ntuple/*.root")

# %%
def extend_array(arr, new_attr, new_attr_name):
    members={n:arr[n] for n in arr.fields}
    members[new_attr_name] = new_attr
    return ak.zip(members)

def add_angle(arr,br=['px','py','pz','e'],name="theta"):
    from coffea.nanoevents.methods import vector
    ak.behavior.update(vector.behavior)

    part =  ak.zip({"x": arr.px,
                    "y": arr.py,
                    "z": arr.pz,
                    "t": arr.e,
                    },
                    with_name="LorentzVector")
    arr = extend_array(arr, part.theta, name)
    return arr

def get_vector(arr):
    from coffea.nanoevents.methods import vector
    ak.behavior.update(vector.behavior)

    part =  ak.zip({"x": arr.px,
                    "y": arr.py,
                    "z": arr.pz,
                    "t": arr.e,
                    },
                    with_name="LorentzVector")
    return part

def flat(x,axis=None): # for now must cast while waiting for coffea to catch up
    try:
        return ak.to_numpy(ak.flatten(x,axis=axis)) 
    except:
        return x

# %%
def pz_smear(pz):
    pz_array = []
    for part in pz:
        for element in part:
            if element <= 50:
                pz_perc = random.gauss(1,0.0404);
            elif element <= 100: 
                pz_perc = random.gauss(1,0.0410);
            elif element <= 250: 
                pz_perc = random.gauss(1,0.0415);
            elif element <= 500: 
                pz_perc = random.gauss(1,0.0420);
            elif element <= 1000: 
                pz_perc = random.gauss(1,0.0435);
            elif element <= 2000:  
                pz_perc = random.gauss(1,0.0477);
            elif element <= 3000:  
                pz_perc = random.gauss(1,0.0523);
            elif element <= 4000:  
                pz_perc = random.gauss(1,0.0573);            
            else:    
                pz_perc = random.gauss(1,0.06);
            pz_array=np.append(pz_array, [pz_perc])
    return (pz_array)

def px1_smear(p):
    px_array = []
    for part in p:
        for element in part:
            if element <= 100:
                px_uncer = random.gauss(0,3.00);
            elif element <= 400: 
                px_uncer = random.gauss(0,3.20);
            elif element <= 500: 
                px_uncer = random.gauss(0,3.20);
            elif element <= 1000: 
                px_uncer = random.gauss(0,3.40);
            elif element <= 1300: 
                px_uncer = random.gauss(0,3.50);
            elif element <= 2000:  
                px_uncer = random.gauss(0,3.85);           
            else:    
                px_uncer = random.gauss(0,3.85);
            px_array=np.append(px_array, [px_uncer])
    return (px_array)

def px2_smear(p):
    px_array = []
    for part in p:
        for element in part:
            if element <= 100:
                px_uncer = random.gauss(0,3.00);
            elif element <= 400: 
                px_uncer = random.gauss(0,3.20);
            elif element <= 500: 
                px_uncer = random.gauss(0,3.20);
            elif element <= 1000: 
                px_uncer = random.gauss(0,3.40);
            elif element <= 1300: 
                px_uncer = random.gauss(0,3.50);
            elif element <= 2000:  
                px_uncer = random.gauss(0,3.85);           
            else:    
                px_uncer = random.gauss(0,3.85);
            px_array=np.append(px_array, [px_uncer])
    return (px_array)

def py1_smear(p):
    py_array = []
    for part in p:
        for element in part:
            if element <= 100:
                py_uncer = random.gauss(0,3.75);
            elif element <= 350: 
                py_uncer = random.gauss(0,3.80);
            elif element <= 500: 
                py_uncer = random.gauss(0,4.20);
            elif element <= 1000: 
                py_uncer = random.gauss(0,4.80);
            elif element <= 1200: 
                py_uncer = random.gauss(0,4.98);
            elif element <= 2000:  
                py_uncer = random.gauss(0,3.85);           
            else:    
                py_uncer = random.gauss(0,5.50);
            py_array=np.append(py_array, [py_uncer])
    return (py_array)

def py2_smear(p):
    py_array = []
    for part in p:
        for element in part:
            if element <= 100:
                py_uncer = random.gauss(0,3.75);
            elif element <= 350: 
                py_uncer = random.gauss(0,3.80);
            elif element <= 500: 
                py_uncer = random.gauss(0,4.20);
            elif element <= 1000: 
                py_uncer = random.gauss(0,4.80);
            elif element <= 1200: 
                py_uncer = random.gauss(0,4.98);
            elif element <= 2000:  
                py_uncer = random.gauss(0,3.85);           
            else:    
                py_uncer = random.gauss(0,5.50);
            py_array=np.append(py_array, [py_uncer])
    return (py_array)

# %%
hists = {}
hists["sim_kaone_hist"] = hist.Hist("Sim Pions",
                                #hist.Cat("Ktype", "Type of Kaons"),      
                                hist.Bin("k", r"Reconstructed $K_s$ Kinetic Energy [MeV]", 40, 0, 3500),
                                hist.Bin("e", r"Electron Energy [MeV]", 40, 0, 1500),
                            )
hists["sim_kaone_hist_thetacut"] = hist.Hist("Sim Pions",      
                                hist.Bin("k", r"Reconstructed $K_s$ Kinetic Energy [MeV]", 40, 0, 3500),
                                hist.Bin("e", r"Electron Energy [MeV]", 40, 0, 1500),
                            )

# %%
def ProcessChunk(chunk, hists):
    ldmx_events = repackage(chunk)

    sim_kaon = ldmx_events['Sim_Kaon']
    sim_kaon_dau1 = ldmx_events['Sim_Kaon_dau1']
    sim_kaon_dau2 = ldmx_events['Sim_Kaon_dau2']
    
    kshort_pdgid = 310
    chargedpion_pdgid = 211
    pion_mass = 139
    kaon_mass = 497.648
    
    kshort_mask = (abs(sim_kaon_dau2.mompdgID)==kshort_pdgid)
    pidau_mask = (abs(sim_kaon_dau2.pdgID)==chargedpion_pdgid)

    pi1 = get_vector(sim_kaon_dau1[pidau_mask & kshort_mask])
    pi2 = get_vector(sim_kaon_dau2[pidau_mask & kshort_mask])
    pisum = (pi1 + pi2)
    
    new_px1 = px1_smear(pi1.p)+flat(pi1.px)
    new_px2 = px2_smear(pi2.p)+flat(pi2.px)
    new_py1 = py1_smear(pi1.p)+flat(pi1.py)
    new_py2 = py2_smear(pi2.p)+flat(pi2.py)
    new_pz1 = pz_smear(pi1.pz)*flat(pi1.pz)
    new_pz2 = pz_smear(pi2.pz)*flat(pi2.pz)
    
    new_psq1 = new_px1**2+new_py1**2+new_pz1**2
    new_psq2 = new_px2**2+new_py2**2+new_pz2**2
    new_e1 = (np.sqrt(new_psq1+pion_mass**2))
    new_e2 = (np.sqrt(new_psq2+pion_mass**2))
    
    from coffea.nanoevents.methods import vector
    ak.behavior.update(vector.behavior)
    pi1_smeared =  ak.zip({"x": new_px1,
                    "y": new_py1,
                    "z": new_pz1,
                    "t": new_e1,
                    },
                    with_name="LorentzVector")
    pi2_smeared =  ak.zip({"x": new_px2,
                    "y": new_py2,
                    "z": new_pz2,
                    "t": new_e2,
                    },
                    with_name="LorentzVector")
    pisum_smeared =(pi1_smeared+pi2_smeared)
    
    hists["sim_kaone_hist"].fill(
                                 k = flat(flat(pisum_smeared.t) - kaon_mass),
                                 e = flat(sim_kaon_dau2[kshort_mask].electrone),
                                )
    
    theta_mask1 = ((40*math.pi/180) >= (flat(pi2.theta)))
    theta_mask2 = ((40*math.pi/180) >= (pi2.theta))
    
    hists["sim_kaone_hist_thetacut"].fill(
                                 k = flat(pisum_smeared[theta_mask1].t) - kaon_mass,
                                 e = flat(sim_kaon_dau2[kshort_mask][theta_mask2].electrone),
                                )
    
    acceptancen = (flat(sim_kaon_dau2.e)).shape
    acceptanced = (flat(sim_kaon_dau2[theta_mask2].e)).shape
    acceptance  = flat(acceptanced) / flat(acceptancen)   
    
    print('acceptance ',acceptance)
    print('acceptanced',acceptanced)
    print('acceptancen',acceptancen)
    #print('acceptance',acceptance)
    #print('acceptance',100*flat((flat(sim_kaon[ytestmask].e).shape)/(flat((flat(sim_kaon.e).shape)))), '%')  
    return flat(acceptance)

# %%
nchunk = 0
percent = 0
for chunk in ldmx_dict:
    nchunk += 1
    returna = ProcessChunk(chunk, hists)
    percent += returna
    print('process', nchunk)
    print('percent', percent/nchunk)
# Out:
# acceptance  [0.51271186]
# acceptanced (121,)
# acceptancen (236,)
# process 1
# percent [0.51271186]
# acceptance  [0.49029126]
# acceptanced (101,)
# acceptancen (206,)
# process 2
# percent [0.50150156]
# acceptance  [0.50909091]
# acceptanced (112,)
# acceptancen (220,)
# process 3
# percent [0.50403135]
# acceptance  [0.53278689]
# acceptanced (130,)
# acceptancen (244,)
# process 4
# percent [0.51122023]
# acceptance  [0.51351351]
# acceptanced (114,)
# acceptancen (222,)
# process 5
# percent [0.51167889]
# acceptance  [0.47488584]
# acceptanced (104,)
# acceptancen (219,)
# process 6
# percent [0.50554671]
# acceptance  [0.52873563]
# acceptanced (138,)
# acceptancen (261,)
# process 7
# percent [0.50885942]
# acceptance  [0.46186441]
# acceptanced (109,)
# acceptancen (236,)
# process 8
# percent [0.50298504]
# acceptance  [0.45895522]
# acceptanced (123,)
# acceptancen (268,)
# process 9
# percent [0.49809284]
# acceptance  [0.46753247]
# acceptanced (108,)
# acceptancen (231,)
# process 10
# percent [0.4950368]
# acceptance  [0.4978355]
# acceptanced (115,)
# acceptancen (231,)
# process 11
# percent [0.49529123]
# acceptance  [0.52968037]
# acceptanced (116,)
# acceptancen (219,)
# process 12
# percent [0.49815699]
# acceptance  [0.47698745]
# acceptanced (114,)
# acceptancen (239,)
# process 13
# percent [0.49652856]
# acceptance  [0.47596154]
# acceptanced (99,)
# acceptancen (208,)
# process 14
# percent [0.49505949]
# acceptance  [0.46956522]
# acceptanced (108,)
# acceptancen (230,)
# process 15
# percent [0.49335987]
# acceptance  [0.50909091]
# acceptanced (112,)
# acceptancen (220,)
# process 16
# percent [0.49434306]
# acceptance  [0.54587156]
# acceptanced (119,)
# acceptancen (218,)
# process 17
# percent [0.49737415]
# acceptance  [0.5]
# acceptanced (118,)
# acceptancen (236,)
# process 18
# percent [0.49752003]
# acceptance  [0.50196078]
# acceptanced (128,)
# acceptancen (255,)
# process 19
# percent [0.49775375]
# acceptance  [0.52208835]
# acceptanced (130,)
# acceptancen (249,)
# process 20
# percent [0.49897048]
# acceptance  [0.56198347]
# acceptanced (136,)
# acceptancen (242,)
# process 21
# percent [0.5019711]
# acceptance  [0.47698745]
# acceptanced (114,)
# acceptancen (239,)
# process 22
# percent [0.50083548]
# acceptance  [0.46255507]
# acceptanced (105,)
# acceptancen (227,)
# process 23
# percent [0.49917112]
# acceptance  [0.47457627]
# acceptanced (112,)
# acceptancen (236,)
# process 24
# percent [0.49814633]
# acceptance  [0.49333333]
# acceptanced (111,)
# acceptancen (225,)
# process 25
# percent [0.49795381]
# acceptance  [0.52054795]
# acceptanced (114,)
# acceptancen (219,)
# process 26
# percent [0.49882282]
# acceptance  [0.56790123]
# acceptanced (138,)
# acceptancen (243,)
# process 27
# percent [0.50138128]
# acceptance  [0.47413793]
# acceptanced (110,)
# acceptancen (232,)
# process 28
# percent [0.5004083]
# acceptance  [0.44897959]
# acceptanced (110,)
# acceptancen (245,)
# process 29
# percent [0.4986349]
# acceptance  [0.49333333]
# acceptanced (111,)
# acceptancen (225,)
# process 30
# percent [0.49845818]
# acceptance  [0.475]
# acceptanced (114,)
# acceptancen (240,)
# process 31
# percent [0.49770146]
# acceptance  [0.49206349]
# acceptanced (124,)
# acceptancen (252,)
# process 32
# percent [0.49752528]
# acceptance  [0.47035573]
# acceptanced (119,)
# acceptancen (253,)
# process 33
# percent [0.49670196]
# acceptance  [0.49579832]
# acceptanced (118,)
# acceptancen (238,)
# process 34
# percent [0.49667538]
# acceptance  [0.52252252]
# acceptanced (116,)
# acceptancen (222,)
# process 35
# percent [0.49741387]
# acceptance  [0.51754386]
# acceptanced (118,)
# acceptancen (228,)
# process 36
# percent [0.49797303]
# acceptance  [0.55335968]
# acceptanced (140,)
# acceptancen (253,)
# process 37
# percent [0.49946997]
# acceptance  [0.46351931]
# acceptanced (108,)
# acceptancen (233,)
# process 38
# percent [0.4985239]
# acceptance  [0.5532646]
# acceptanced (161,)
# acceptancen (291,)
# process 39
# percent [0.49992751]
# acceptance  [0.496]
# acceptanced (124,)
# acceptancen (250,)
# process 40
# percent [0.49982932]
# acceptance  [0.53070175]
# acceptanced (121,)
# acceptancen (228,)
# process 41
# percent [0.50058231]
# acceptance  [0.53389831]
# acceptanced (126,)
# acceptancen (236,)
# process 42
# percent [0.50137555]
# acceptance  [0.50431034]
# acceptanced (117,)
# acceptancen (232,)
# process 43
# percent [0.5014438]
# acceptance  [0.48809524]
# acceptanced (123,)
# acceptancen (252,)
# process 44
# percent [0.50114042]
# acceptance  [0.53181818]
# acceptanced (117,)
# acceptancen (220,)
# process 45
# percent [0.50182215]
# acceptance  [0.4813278]
# acceptanced (116,)
# acceptancen (241,)
# process 46
# percent [0.50137662]
# acceptance  [0.54468085]
# acceptanced (128,)
# acceptancen (235,)
# process 47
# percent [0.50229799]
# acceptance  [0.49315068]
# acceptanced (108,)
# acceptancen (219,)
# process 48
# percent [0.50210742]
# acceptance  [0.5254902]
# acceptanced (134,)
# acceptancen (255,)
# process 49
# percent [0.50258462]
# acceptance  [0.51452282]
# acceptanced (124,)
# acceptancen (241,)
# process 50
# percent [0.50282338]
# acceptance  [0.49790795]
# acceptanced (119,)
# acceptancen (239,)
# process 51
# percent [0.502727]
# acceptance  [0.53941909]
# acceptanced (130,)
# acceptancen (241,)
# process 52
# percent [0.50343262]
# acceptance  [0.50205761]
# acceptanced (122,)
# acceptancen (243,)
# process 53
# percent [0.50340667]
# acceptance  [0.53539823]
# acceptanced (121,)
# acceptancen (226,)
# process 54
# percent [0.50399911]
# acceptance  [0.5106383]
# acceptanced (120,)
# acceptancen (235,)
# process 55
# percent [0.50411982]
# acceptance  [0.56097561]
# acceptanced (138,)
# acceptancen (246,)
# process 56
# percent [0.5051351]
# acceptance  [0.48917749]
# acceptanced (113,)
# acceptancen (231,)
# process 57
# percent [0.50485515]
# acceptance  [0.50988142]
# acceptanced (129,)
# acceptancen (253,)
# process 58
# percent [0.50494181]
# acceptance  [0.45081967]
# acceptanced (110,)
# acceptancen (244,)
# process 59
# percent [0.50402448]
# acceptance  [0.48770492]
# acceptanced (119,)
# acceptancen (244,)
# process 60
# percent [0.50375249]
# acceptance  [0.47058824]
# acceptanced (120,)
# acceptancen (255,)
# process 61
# percent [0.50320881]
# acceptance  [0.51598174]
# acceptanced (113,)
# acceptancen (219,)
# process 62
# percent [0.50341483]
# acceptance  [0.56756757]
# acceptanced (126,)
# acceptancen (222,)
# process 63
# percent [0.50443312]
# acceptance  [0.55855856]
# acceptanced (124,)
# acceptancen (222,)
# process 64
# percent [0.50527883]
# acceptance  [0.56652361]
# acceptanced (132,)
# acceptancen (233,)
# process 65
# percent [0.50622106]
# acceptance  [0.52868852]
# acceptanced (129,)
# acceptancen (244,)
# process 66
# percent [0.50656148]
# acceptance  [0.46759259]
# acceptanced (101,)
# acceptancen (216,)
# process 67
# percent [0.50597985]
# acceptance  [0.53968254]
# acceptanced (136,)
# acceptancen (252,)
# process 68
# percent [0.50647548]
# acceptance  [0.52]
# acceptanced (117,)
# acceptancen (225,)
# process 69
# percent [0.50667149]
# acceptance  [0.52360515]
# acceptanced (122,)
# acceptancen (233,)
# process 70
# percent [0.5069134]
# acceptance  [0.49603175]
# acceptanced (125,)
# acceptancen (252,)
# process 71
# percent [0.50676013]

# %%
print(hists["sim_kaone_hist"])

fig, ax = plt.subplots()
hist.plot2d(hists["sim_kaone_hist"], xaxis='k', ax=ax, patch_opts=POPTS);
ax.text(2900, 1400,r'All $\theta$')

fig, ax = plt.subplots()
hist.plot2d(hists["sim_kaone_hist_thetacut"], xaxis='k', ax=ax, patch_opts=POPTS);
ax.text(2900, 1400,r'$\theta$<40$^\circ$')

x = np.arange(0, 3250, 1)
#ytest = -0.97* x + 3350
#ax.plot(x, ytest, '-')

#y0 = -x
#y1 = (-4.35*(x)+2150)80% is above
#y2 = (-3.35*(x)+2150)60% is above
#y3 = (-2.50*(x)+2150)40% is above
#y4 = (-1.75*(x)+3350)20% is above
#y5 = (-0.97*(x)+3350)3% is above
#y6 = -1*x+3350

y0 = -x
y1 = (-4.35*(x)+2150)
y2 = (-3.35*(x)+2150)
y3 = (-2.50*(x)+2150)
y4 = (-1.75*(x)+3350)
y5 = (-0.97*(x)+3350)
y6 = (3350)
# Out:
# <Hist (k,e) instance at 0x12fa30f70>

# %%
print(hists["Target_kaone_hist"])

fig, ax = plt.subplots()
hist.plot2d(hists["Target_kaone_hist"].integrate('Ktype', ['Kshort']), xaxis='k', ax=ax, patch_opts=POPTS);
x = np.arange(0, 3250, 1)
ytest = (-1.25*(x)+2660)
#ax.plot(x, ytest, '-')


fig, ax = plt.subplots()
ax.set_xlim(0, 3500)
ax.set_ylim(0, 1400)
y0 = -x
y1 = (-4.35*(x)+2150)
y2 = (-3.35*(x)+2150)
y3 = (-2.50*(x)+2150)
y4 = (-1.75*(x)+3350)
y5 = (-0.97*(x)+3350)
y6 = (3350)
ax.plot(x, y5, '-')

ax.fill_between(x, y0, y1, where=(y1 > y0), facecolor='red', alpha=0.5)
ax.fill_between(x, y1, y2, where=(y2 > y1), facecolor='orange', alpha=0.5)
ax.fill_between(x, y2, y3, where=(y3 > y2), facecolor='yellow', alpha=0.5)
ax.fill_between(x, y3, y4, where=(y4 > y3), facecolor='green', alpha=0.5)
ax.fill_between(x, y4, y5, where=(y5 > y4), facecolor='blue', alpha=0.5)
#ax.fill_between(x, y5, y6, where=(y6 > y5), facecolor='yellow', alpha=0.5)
ax.set_ylabel('Electron Energy (MeV)', loc='top')
ax.set_xlabel('Kaon Kinetic Energy (MeV)', loc='right')
ax.text(50, 200, '20%')
ax.text(400, 100, '20%')
ax.text(500, 300, '20%')
ax.text(1200, 200, '20%')
ax.text(2500, 200, '20%')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-07cb664104e6> in <module>
# ----> 1 print(hists["Target_kaone_hist"])
#       2
#       3 fig, ax = plt.subplots()
#       4 hist.plot2d(hists["Target_kaone_hist"].integrate('Ktype', ['Kshort']), xaxis='k', ax=ax, patch_opts=POPTS);
#       5 x = np.arange(0, 3250, 1)
#
# KeyError: 'Target_kaone_hist'
